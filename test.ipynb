# %%
# !zip -r my_archive.zip .
# Out:
#   adding: frontend/ (stored 0%)
#   adding: frontend/src/ (stored 0%)
#   adding: frontend/src/hooks/ (stored 0%)
#   adding: frontend/src/hooks/use-toast.js (deflated 65%)
#   adding: frontend/src/index.css (deflated 70%)
#   adding: frontend/src/App.js (deflated 46%)
#   adding: frontend/src/components/ (stored 0%)
#   adding: frontend/src/components/About.jsx (deflated 67%)
#   adding: frontend/src/components/Footer.jsx (deflated 70%)
#   adding: frontend/src/components/Hero.jsx (deflated 66%)
#   adding: frontend/src/components/HomePage.jsx (deflated 61%)
#   adding: frontend/src/components/ui/ (stored 0%)
#   adding: frontend/src/components/ui/pagination.jsx (deflated 70%)
#   adding: frontend/src/components/ui/drawer.jsx (deflated 70%)
#   adding: frontend/src/components/ui/aspect-ratio.jsx (deflated 34%)
#   adding: frontend/src/components/ui/resizable.jsx (deflated 67%)
#   adding: frontend/src/components/ui/context-menu.jsx (deflated 80%)
# ...

# %%
# !apt-get update
# !apt-get install -y zip
# Out:
# Get:1 http://deb.debian.org/debian bookworm InRelease [151 kB]
# Get:2 http://deb.debian.org/debian bookworm-updates InRelease [55.4 kB]
# Get:3 http://deb.debian.org/debian-security bookworm-security InRelease [48.0 kB]
# Hit:4 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0 InRelease
# Hit:5 https://deb.nodesource.com/node_20.x nodistro InRelease
# Fetched 254 kB in 1s (277 kB/s)
# Reading package lists... Done
# N: Repository 'http://deb.debian.org/debian bookworm InRelease' changed its 'Suite' value from 'stable' to 'oldstable'
# N: Repository 'http://deb.debian.org/debian bookworm-updates InRelease' changed its 'Suite' value from 'stable-updates' to 'oldstable-updates'
# N: Repository 'http://deb.debian.org/debian-security bookworm-security InRelease' changed its 'Suite' value from 'stable-security' to 'oldstable-security'
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ...
